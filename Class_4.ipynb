# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayamm03/Skill-Code/blob/main/Class_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Dataset/WWTP_Dataset.csv'
df = pd.read_csv(file_path)

# %%
print("loaded: ", df.shape)
# Out:
# loaded:  (2400, 20)

# %%
df.head()
# Out:
#              timestamp  rainfall_mm  storm_event_flag  wet_dry_index  \
# 0  2022-01-01 00:00:00     7.181038                 0              1
# 1  2022-01-01 01:00:00     4.483394                 0              1
# 2  2022-01-01 02:00:00     4.146851                 0              1
# 3  2022-01-01 03:00:00     4.146907                 0              1
# 4  2022-01-01 04:00:00    13.949143                 1              1
#
#    inflow_m3_hr      BOD_in      COD_in      TSS_in      TN_in      TP_in  \
# 0    843.877521  297.664855  485.688948  244.743472  28.824194  13.231587
# 1    787.658324  414.195173  885.847933  180.130920  65.925933   4.680308
# 2    922.716775  273.873357  468.756012  183.693417  64.654116   7.809749
# 3    912.509357  311.248126  872.061495  371.518411  74.200461   3.903091
# 4   1562.286176  247.184848  531.402865  329.163547  20.509161   9.542533
#
#       NH4_in  aeration_rate  sludge_recirculation  chemical_dose        HRT  \
# ...

# %%
df.tail()
# Out:
#                 timestamp  rainfall_mm  storm_event_flag  wet_dry_index  \
# 2395  2022-04-10 19:00:00    16.978483                 1              1
# 2396  2022-04-10 20:00:00    10.113793                 1              1
# 2397  2022-04-10 21:00:00     4.818769                 0              1
# 2398  2022-04-10 22:00:00     1.034662                 0              0
# 2399  2022-04-10 23:00:00     0.533326                 0              0
#
#       inflow_m3_hr      BOD_in       COD_in      TSS_in      TN_in      TP_in  \
# 2395   1363.243669  341.362900   615.249716  449.151788  56.573649   4.051709
# 2396   1647.627656  550.892211  1321.946180  455.466158  60.904157   8.184055
# 2397    787.159786  422.410463   408.583838  146.578724  50.332503   6.850381
# 2398    529.606853  220.706134   778.355415  279.259933  61.653913  11.478730
# 2399    489.477532  422.477566   574.188216  341.542464  30.365279  13.442900
#
# ...

# %%
df.describe()
# Out:
#        rainfall_mm  storm_event_flag  wet_dry_index  inflow_m3_hr  \
# count  2400.000000       2400.000000    2400.000000   2400.000000
# mean      6.104493          0.163750       0.750000    868.090365
# std       4.232492          0.370126       0.433103    321.981270
# min       0.077581          0.000000       0.000000    450.040154
# 25%       3.001297          0.000000       0.750000    711.314017
# 50%       5.175488          0.000000       1.000000    835.726341
# 75%       8.079237          0.000000       1.000000    907.475448
# max      40.830698          1.000000       1.000000   1649.762190
#
#             BOD_in       COD_in       TSS_in        TN_in        TP_in  \
# count  2400.000000  2400.000000  2400.000000  2400.000000  2400.000000
# mean    321.982769   662.466132   308.489707    50.415856     9.121099
# std     109.167110   237.638128   110.691026    17.273364     3.453742
# min     150.015848   300.094647   120.501550    20.015147     3.007340
# ...

# %%
print("Missing value per column:\n", df.isnull().sum(), sep="")
# Out:
# Missing value per column:
# timestamp                   0
# rainfall_mm                 0
# storm_event_flag            0
# wet_dry_index               0
# inflow_m3_hr                0
# BOD_in                      0
# COD_in                      0
# TSS_in                      0
# TN_in                       0
# TP_in                       0
# NH4_in                      0
# aeration_rate               0
# sludge_recirculation        0
# chemical_dose               0
# HRT                         0
# SRT                         0
# DO_setpoint                 0
# energy_kwh                  0
# total_operational_cost      0
# effluent_violation_index    0
# dtype: int64
