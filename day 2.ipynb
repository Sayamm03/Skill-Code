# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayamm03/Skill-Code/blob/main/day%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(12345, "\n", "skill", "\n", 45.67, sep="")
# Out:
# 12345
# skill
# 45.67

# %%
print(123 * 456, ",", 456-765)
# Out:
# 56088 , -309

# %%
x = 12
print(x)
# Out:
# 12

# %%
number1 = 1234
number2 = 4567
sum = number1 + number2
sub = number1 - number2
print("number1 + number2 =", sum)
print(sum, sub)
# Out:
# number1 + number2 = 5801
# 5801 -3333

# %%
N1 = 1234
N2 = 456.877
R = N1 + N2
print(type(R), R)
# Out:
# <class 'float'> 1690.877

# %%
N1 = 1234
N2 = 456.877
R = N1 + int(N2)
print(type(R))
# Out:
# <class 'int'>

# %%
print("{:.2f}".format(4653.76578))
# Out:
# 4653.77

# %%
A = 5643.654754337
B = 5864.875975443
sum = A + B
print("{:.2f}".format(sum))
# Out:
# 11508.53

# %%
A = 56
B = 85
sub = A - B
mult = A * B
div = A / B
print(sub)
print(mult)
print("{:.2f}".format(div))
# Out:
# -29
# 4760
# 0.66

# %%
num1 = int(input("Enter the 1st number: "))
num2 = int(input("Enter the 2nd number: "))
print("Result: ", num1 + num2)
print("Division: ", num1 / num2)
print("Division: ", num1 // num2)
print("R: ", num1 % num2)
# Out:
# Enter the 1st number: 500
# Enter the 2nd number: 130
# Result:  630
# Division:  3.8461538461538463
# Division:  3
# R:  110

# %%
b = float(input())
h = float(input())
area = 0.5 * b * h
print("{:.2f}".format(area))
# Out:
# 10.35335
# 10.54324
# 54.58

# %%
name = input("Name: ")
batch = input("Batch: ")
hometown = input("Hometown: ")
print(name)
print(batch)
print(hometown)
# Out:
# Name: Sayam
# Batch: 2
# Hometown: Chandpur
# Sayam
# 2
# Chandpur

# %%
num = 6747
print(num)

num = 9865
print(num)
# Out:
# 6747
# 9865

# %%
a = 10
b = 20
num1 = int(a)
num2 = int(b)
print(num1, type(num1))
print(num2, type(num2))
# Out:
# 10 <class 'int'>
# 20 <class 'int'>

# %%
num1 = 10
num2 = 5

res1 = num1 & num2
res2 = num1 | num2
res3 = num1 ^ num2
res4 = num1 >> num2

print(res1, res2, res3, res4)
# Out:
# 0 15 15 0

# %%
num = int(input())

res = num % 5
print(res)

if res == 0:
  print("This is an EVEN number")
else:
  print("This is an ODD numer")
# Out:
# 30
# 0
# This is an EVEN number

# %%
## H6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.
A = int(input("Enter 1st number: "))
operator = input("Enter operator: ")
B = int(input("Enter 2nd number:"))


if operator == "+":
    result = A + B
elif operator == "-":
    result = A - B
elif operator == "*":
      result = A * B
else:
      result = A // B
print(result)
# Out:
# Enter 1st number: 40
# Enter operator: //
# Enter 2nd number:10
# 4

# %%
#H7: Write a program that asks the user to enter a single character and determines whether it is a vowel or a consonant.

char = input("Enter a character: ")

if len(char) == 1 and char.isalpha():
  if char in "aeiou":
    print("vowel")
  else:
    print("consonant")
# Out:
# Enter a character: b
# consonant

# %%
## H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.

T = float(input("Enter value: "))
convert = input("C or F: ")

if convert == "C":
  result = (T-32) * 5/9
else:
  result = (T * 9/5) + 32
print(result)
# Out:
# Enter value: 23
# C or F: C
# -5.0

# %%
## H9: Write a program that asks the user to enter three numbers and determines which one is the largest.

num1 = int(input("Enter 1st number: "))
num2 = int(input("Enter 2nd number: "))
num3 = int(input("Enter 3rd number: "))

if num1 >= num2 or num3:
  print("large")
elif num2 >= num1 or num3:
  print("large")
else:
  print("large")
# Out:
# Enter 1st number: 30
# Enter 2nd number: 20
# Enter 3rd number: 40
# large

# %%
# H10: Write a program that prompts the user to input a number N and prints all even numbers between 1 and N using a for loop.

n = int(input("input a number: "))
for i in range(1, n+1):
  if i % 2 == 0:
    print(i)
# Out:
# input a number: 7
# 2
# 4
# 6

# %%
# H11: Write a program that prompts the user to input a number N and calculates the sum of all numbers from 1 to N that are divisible by 3 or 5.

n = int(input("Input a number: "))
total = 0
for i in range(1, n+1):
  if i % 3 == 0 or i % 5 == 0:
    total += i
print(total)
# Out:
# Input a number: 40
# 408

# %%
# H12: Write a program that prompts the user to input a number n and prints the multiplication table of n (1 to 10) using a for loop.

n = int(input("Input a number: "))

for i in range(1, 11):
  print(n * i)
# Out:
# Input a number: 5
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
