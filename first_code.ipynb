# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayamm03/Skill-Code/blob/main/first_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Sayam")
# Out:
# Sayam
